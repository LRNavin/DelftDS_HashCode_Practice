# %%
import numpy as np
import sys

# %%
warehouse = open('./mother_of_all_warehouses.in', 'r')
busyday = open('./busy_day.in', 'r')
redundancy = open('./redundancy.in', 'r')

for house in warehouse:
    print(house)    
# print (busyday)    
# print (redundancy)
# Out:
# 240 400 20 144612 200
#
# 1000
#
# ...
